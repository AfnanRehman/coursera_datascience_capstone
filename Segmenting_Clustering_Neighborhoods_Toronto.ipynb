# %%
# Scraping wiki table
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print (i,name)
    col.append((name,[]))
# Out:
# 1 Postcode
# 2 Borough
# 3 Neighbourhood

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
# Check to make sure everything loaded in dataframe
df.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %%
print(df.shape)
# Out:
# (288, 3)

# %%
df2 = pd.read_csv('Geospatial_Coordinates.csv')
zips = df2.PostalCode.tolist()

# %%
df2.join(df, lsuffix='Postcode', rsuffix='PostalCode')
# Out:
#     PostalCode   Latitude  Longitude Postcode           Borough  \
# 0          M1B  43.806686 -79.194353      M1A      Not assigned
# 1          M1C  43.784535 -79.160497      M2A      Not assigned
# 2          M1E  43.763573 -79.188711      M3A        North York
# 3          M1G  43.770992 -79.216917      M4A        North York
# 4          M1H  43.773136 -79.239476      M5A  Downtown Toronto
# 5          M1J  43.744734 -79.239476      M5A  Downtown Toronto
# 6          M1K  43.727929 -79.262029      M6A        North York
# 7          M1L  43.711112 -79.284577      M6A        North York
# 8          M1M  43.716316 -79.239476      M7A      Queen's Park
# 9          M1N  43.692657 -79.264848      M8A      Not assigned
# 10         M1P  43.757410 -79.273304      M9A         Etobicoke
# 11         M1R  43.750072 -79.295849      M1B       Scarborough
# 12         M1S  43.794200 -79.262029      M1B       Scarborough
# 13         M1T  43.781638 -79.304302      M2B      Not assigned
# 14         M1V  43.815252 -79.284577      M3B        North York
# 15         M1W  43.799525 -79.318389      M4B         East York
# 16         M1X  43.836125 -79.205636      M4B         East York
# 17         M2H  43.803762 -79.363452      M5B  Downtown Toronto
# 18         M2J  43.778517 -79.346556      M5B  Downtown Toronto
# 19         M2K  43.786947 -79.385975      M6B        North York
# 20         M2L  43.757490 -79.374714      M7B      Not assigned
# 21         M2M  43.789053 -79.408493      M8B      Not assigned
# 22         M2N  43.770120 -79.408493      M9B         Etobicoke
# 23         M2P  43.752758 -79.400049      M9B         Etobicoke
# 24         M2R  43.782736 -79.442259      M9B         Etobicoke
# 25         M3A  43.753259 -79.329656      M9B         Etobicoke
# 26         M3B  43.745906 -79.352188      M9B         Etobicoke
# 27         M3C  43.725900 -79.340923      M1C       Scarborough
# 28         M3H  43.754328 -79.442259      M1C       Scarborough
# 29         M3J  43.767980 -79.487262      M1C       Scarborough
# ..         ...        ...        ...      ...               ...
# 73         M6C  43.693781 -79.428191      M7H      Not assigned
# 74         M6E  43.689026 -79.453512      M8H      Not assigned
# 75         M6G  43.669542 -79.422564      M9H      Not assigned
# 76         M6H  43.669005 -79.442259      M1J       Scarborough
# 77         M6J  43.647927 -79.419750      M2J        North York
# 78         M6K  43.636847 -79.428191      M2J        North York
# 79         M6L  43.713756 -79.490074      M2J        North York
# 80         M6M  43.691116 -79.476013      M3J        North York
# 81         M6N  43.673185 -79.487262      M3J        North York
# 82         M6P  43.661608 -79.464763      M4J         East York
# 83         M6R  43.648960 -79.456325      M5J  Downtown Toronto
# 84         M6S  43.651571 -79.484450      M5J  Downtown Toronto
# 85         M7A  43.662301 -79.389494      M5J  Downtown Toronto
# 86         M7R  43.636966 -79.615819      M6J      West Toronto
# 87         M7Y  43.662744 -79.321558      M6J      West Toronto
# 88         M8V  43.605647 -79.501321      M7J      Not assigned
# 89         M8W  43.602414 -79.543484      M8J      Not assigned
# 90         M8X  43.653654 -79.506944      M9J      Not assigned
# 91         M8Y  43.636258 -79.498509      M1K       Scarborough
# 92         M8Z  43.628841 -79.520999      M1K       Scarborough
# 93         M9A  43.667856 -79.532242      M1K       Scarborough
# 94         M9B  43.650943 -79.554724      M2K        North York
# 95         M9C  43.643515 -79.577201      M3K        North York
# 96         M9L  43.756303 -79.565963      M3K        North York
# 97         M9M  43.724766 -79.532242      M4K      East Toronto
# 98         M9N  43.706876 -79.518188      M4K      East Toronto
# 99         M9P  43.696319 -79.532242      M5K  Downtown Toronto
# 100        M9R  43.688905 -79.554724      M5K  Downtown Toronto
# 101        M9V  43.739416 -79.588437      M6K      West Toronto
# 102        M9W  43.706748 -79.594054      M6K      West Toronto
#
#                Neighbourhood\n
# 0               Not assigned\n
# 1               Not assigned\n
# 2                  Parkwoods\n
# 3           Victoria Village\n
# 4               Harbourfront\n
# 5                Regent Park\n
# 6           Lawrence Heights\n
# 7             Lawrence Manor\n
# 8               Not assigned\n
# 9               Not assigned\n
# 10          Islington Avenue\n
# 11                     Rouge\n
# 12                   Malvern\n
# 13              Not assigned\n
# 14           Don Mills North\n
# 15          Woodbine Gardens\n
# 16             Parkview Hill\n
# 17                   Ryerson\n
# 18           Garden District\n
# 19                 Glencairn\n
# 20              Not assigned\n
# 21              Not assigned\n
# 22                Cloverdale\n
# 23                 Islington\n
# 24              Martin Grove\n
# 25          Princess Gardens\n
# 26           West Deane Park\n
# 27            Highland Creek\n
# 28                Rouge Hill\n
# 29                Port Union\n
# ..                         ...
# 73              Not assigned\n
# 74              Not assigned\n
# 75              Not assigned\n
# 76       Scarborough Village\n
# 77                  Fairview\n
# 78                Henry Farm\n
# 79                    Oriole\n
# 80            Northwood Park\n
# 81           York University\n
# 82              East Toronto\n
# 83         Harbourfront East\n
# 84           Toronto Islands\n
# 85             Union Station\n
# 86           Little Portugal\n
# 87                   Trinity\n
# 88              Not assigned\n
# 89              Not assigned\n
# 90              Not assigned\n
# 91      East Birchmount Park\n
# 92                   Ionview\n
# 93              Kennedy Park\n
# 94           Bayview Village\n
# 95               CFB Toronto\n
# 96            Downsview East\n
# 97         The Danforth West\n
# 98                 Riverdale\n
# 99           Design Exchange\n
# 100  Toronto Dominion Centre\n
# 101                 Brockton\n
# 102         Exhibition Place\n
#
# [103 rows x 6 columns]
